# %% [markdown]
# <a href="https://colab.research.google.com/github/muzahid626/python_Id_191-15-2559/blob/master/week_3_lab_work_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# built-in functions

# %%
print("Hi, I am semi-colon. Do you miss me?")
print("Let me know if you miss me or not. ")
s=input()

a=10
b=21
print(max(a,b))
print(min(a,b))

c=10.4
d=int(c)
print(d)

e="python"
print(type(e))
# Out:
# Hi, I am semi-colon. Do you miss me?
# Let me know if you miss me or not.
# 1
# 21
# 10
# 10
# <class 'str'>

# %% [markdown]
# user defined function

# %%
def add(a, b):
    c=a+b
    return c

a=int(input("Enter a number: "))
b=int(input("Enter a number: "))
d=add(a,b)
print("The sum is", d)
# Out:
# Enter a number: 1
# Enter a number: 1
# The sum is 2

# %% [markdown]
# function with multiple parameters

# %%
def divisor(x,y,m):
    if x%m==0 and y%m==0:
        print("%d & %d are divisible by %d"%(x,y,m))
    elif x%m==0:
        print("only %d is divisible by %d"%(x,m))
    elif y%m==0:
        print("only %d is divisible by %d"%(y,m))
    else:
        print("none of %d & %d is divisible by %d"%(x,y,d))

divisor(10,20,5)
divisor(12,20,5)
divisor(10,22,5)
divisor(2,5,3)
# Out:
# 10 & 20 are divisible by 5
# only 20 is divisible by 5
# only 10 is divisible by 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b0b4e128d60d> in <module>()
#      12 divisor(12,20,5)
#      13 divisor(10,22,5)
# ---> 14 divisor(2,5,3)
#
# <ipython-input-2-b0b4e128d60d> in divisor(x, y, m)
#       7         print("only %d is divisible by %d"%(y,m))
#       8     else:
# ----> 9         print("none of %d & %d is divisible by %d"%(x,y,d))
#      10
#      11 divisor(10,20,5)
#
# NameError: name 'd' is not defined

# %% [markdown]
# function without parameter

# %%
def summation():
    a=3+8
    return a

b=summation()
print(b)
# Out:
# 11

# %% [markdown]
# function with default parameter value

# %%
def check(a=0):
    if a==0:
        print("Zero")
    elif a>0:
        print("Positive")
    else:
        print("Negative")

check()     #without parameter
check(-4)   #with parameter
# Out:
# Zero
# Negative

# %% [markdown]
# local scope

# %%
def local_scope():
    x=7
    print(x)

local_scope()
print(x)
# Out:
# 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-15d63c0e104f> in <module>()
#       4
#       5 local_scope()
# ----> 6 print(x)
#
# NameError: name 'x' is not defined

# %%
def local_scope():
    x=7
    return x

a=local_scope()
print(a)
print(x)

# %% [markdown]
# global scope

# %%
x=10

def global_scope():
    print(x)

print(x)
global_scope()

# %%
def global_scope():
    global x
    x=10

global_scope()
print(x)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # python standard library and csv module

# %%
import csv

with open('gdrive/My Drive/Colab Notebooks/Lab work/week 3/prog_book.csv', newline='') as csvfile:
    tmp = csv.reader(csvfile, delimiter=' ', quotechar='|')
    for row in tmp:
        print(', '.join(row))
# Out:
# Rating,Reviews,Book_title,Description,Number_Of_Pages,Type,Price
# 4.17,"3,829",The, Elements, of, Style,"This, style, manual, offers, practical, advice, on, improving, writing, skills., Throughout,, the, emphasis, is, on, promoting, a, plain, English, style., This, little, book, can, help, you, communicate, more, effectively, by, showing, you, how, to, enliven, your, sentences.",105,Hardcover,9.323529412
# 4.01,"1,406","The, Information:, A, History,, a, Theory,, a, Flood","James, Gleick,, the, author, of, the, best, sellers, Chaos, and, Genius,, now, brings, us, a, work, just, as, astonishing, and, masterly:, a, revelatory, chronicle, and, meditation, that, shows, how, information, has, become, the, modern, era’s, defining, quality—the, blood,, the, fuel,, the, vital, principle, of, our, world.
# ,
# The, story, of, information, begins, in, a, time, profoundly, unlike, our, own,, when, every, thought, and
#
#
#
# ...more",527,Hardcover,11
# ...

# %%
import pandas as panda

# %%
pip install pandas

# %%
panda.read_csv('gdrive/My Drive/Colab Notebooks/Lab work/week 3/prog_book.csv')
# Out:
#      Rating Reviews  ...                   Type       Price
# 0      4.17   3,829  ...              Hardcover    9.323529
# 1      4.01   1,406  ...              Hardcover   11.000000
# 2      3.33       0  ...         Kindle Edition   11.267647
# 3      3.97   1,658  ...              Hardcover   12.873529
# 4      4.06   1,325  ...         Kindle Edition   13.164706
# ..      ...     ...  ...                    ...         ...
# 266    3.76       0  ...              Hardcover  203.108823
# 267    3.94      22  ...              Paperback  212.097059
# 268    4.49      36  ...  Boxed Set - Hardcover  220.385294
# 269    4.77       4  ...              Hardcover  220.385294
# 270    3.84       5  ...              Hardcover  235.650000
#
# [271 rows x 7 columns]

# %%
data=panda.read_csv('gdrive/My Drive/Colab Notebooks/Lab work/week 3/prog_book.csv')

# %%
data.head(50)
# Out:
#     Rating Reviews  ...            Type      Price
# 0     4.17   3,829  ...       Hardcover   9.323529
# 1     4.01   1,406  ...       Hardcover  11.000000
# 2     3.33       0  ...  Kindle Edition  11.267647
# 3     3.97   1,658  ...       Hardcover  12.873529
# 4     4.06   1,325  ...  Kindle Edition  13.164706
# 5     3.84     117  ...       Paperback  14.188235
# 6     4.09   5,938  ...       Hardcover  14.232353
# 7     4.15   1,817  ...       Hardcover  14.364706
# 8     3.87   2,093  ...       Hardcover  14.502941
# 9     4.62       0  ...       Paperback  14.641176
# 10    4.03     160  ...       Hardcover  15.229412
# 11    3.78     481  ...       Hardcover  15.229412
# 12    3.73      33  ...       Paperback  15.326471
# 13    3.87   1,255  ...       Hardcover  15.682353
# 14    3.87     593  ...       Hardcover  15.885294
# 15    3.95     417  ...       Hardcover  16.073529
# 16    3.85      80  ...       Paperback  16.367647
# ...

# %%
data.tail(20)
# Out:
#      Rating Reviews  ...                   Type       Price
# 251    4.42      38  ...              Hardcover  103.173529
# 252    4.11      56  ...              Hardcover  103.461765
# 253    4.11      56  ...              Paperback  103.461765
# 254    3.96      15  ...              Hardcover  103.608823
# 255    3.67       2  ...              Hardcover  105.650000
# 256    4.13      14  ...              Hardcover  107.747059
# 257    3.87      13  ...              Paperback  108.367647
# 258    4.16      16  ...              Hardcover  113.302941
# 259    4.18     130  ...              Hardcover  115.750000
# 260    3.45       1  ...              Hardcover  117.988235
# 261    3.82       0  ...              Hardcover  119.202941
# 262    4.08      56  ...              Hardcover  126.579412
# 263    3.77       0  ...              Hardcover  139.435294
# 264    3.82       0  ...              Hardcover  143.138235
# 265    4.26       5  ...              Hardcover  176.144118
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      Rating Reviews  ...                   Type       Price
# 0      4.17   3,829  ...              Hardcover    9.323529
# 1      4.01   1,406  ...              Hardcover   11.000000
# 2      3.33       0  ...         Kindle Edition   11.267647
# 3      3.97   1,658  ...              Hardcover   12.873529
# 4      4.06   1,325  ...         Kindle Edition   13.164706
# ..      ...     ...  ...                    ...         ...
# 266    3.76       0  ...              Hardcover  203.108823
# 267    3.94      22  ...              Paperback  212.097059
# 268    4.49      36  ...  Boxed Set - Hardcover  220.385294
# 269    4.77       4  ...              Hardcover  220.385294
# 270    3.84       5  ...              Hardcover  235.650000
#
# [271 rows x 7 columns]>

# %%
data.shape
# Out:
# (271, 7)

# %% [markdown]
# python standard library and math module

# %%
import math

print(math.pi)          

x=9.2
print(math.ceil(x))     
print(math.floor(x))    

print(math.sin(78))     

print(math.pow(2,3))    

print(math.sqrt(16))
# Out:
# 3.141592653589793
# 10
# 9
# 0.5139784559875352
# 8.0
# 4.0
